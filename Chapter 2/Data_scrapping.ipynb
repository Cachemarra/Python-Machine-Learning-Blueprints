# %% [markdown]
# # Data Scrapping Renthop.com
# This book focus on create an app to help choosing a department on NYC.
# The main content is based on Python Machine Learning Blueprints book by Packt.
#
# ---------------------------
#
# Importing libraries

# %%
# Importing libraries
import numpy as np
import pandas as pd
import requests
import matplotlib.pyplot as plt

# Inline plots
# %matplotlib inline

# %% [markdown]
# As stated in the title, we're going to use NYC apartment data in our model. The url is the next:
# https://www.renthop.com/nyc/apartments-for-rent
#
# First we're going to do a quick test and be sure that we can retrieve the page.

# %%
r = requests.get('https://www.renthop.com/nyc/apartments-for-rent')
r.content

# %% [markdown]
# I deleted the answer of r.content as it is too much, but the output should be the html code of the whole pag. You can try
# copying the request into an HTML text editor to see what's downloaded. It would show a raw page as it doesn't download the CSS file, but all content is there.
# That makes more easier to scrapping as the page doesn't use much JS code for rendering.
#
# If the data is behind JS code we most use Selenium to interact with it.

# %% [markdown]
# Now examine the page elements to see how we can parse the page data:
#
# 1. Open the RentHop site and clic anywhere.
# 2. Click on **Inspect**.
# 3. Click on the square with arrow button and then click on the data on the page. It will highlight the code part.
# You can see that each listing's data is in a table and the first td tag contains the price, the second is the number of bedrooms and
# the thhird the number of bathrooms. The address can be found in an anchor or a tag.
#
# --------------------
#
# To do the HTML parsing, we are going to use BeautifulSoup library.
#
# We simply need to pass the page content into the BeautifulSoup class.

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(r.content, 'html5lib')

# Now we can use the soup object to parsing the apartment data. The first thing
# is retrieve div tag that contains listing data on the page.

# Looking for all div classes that contain 'search.info'.
listing_divs = soup.select('div[class*=search-info]')
listing_divs
# Out:
# [<div class="search-info d-block d-md-inline-block align-top">
#  <div>
#  <div class="float-right font-size-9" style="padding-top: 2px;">
#  <span class="font-gray-2 d-none d-sm-inline-block"></span>
#  </div>
#  <a class="font-size-12 b" href="https://www.renthop.com/listings/775-columbus-ave/07c/62453191" id="listing-62453191-title" style="text-decoration: none; line-height: 100%;">
#  775 Columbus Avenue, Apt 07C
#  </a>
#  <div class="font-gray-1 font-size-8 overflow-ellipsis" id="listing-62453191-neighborhoods" style="margin-top: 0px;">
#  Manhattan Valley, Upper West Side, Upper Manhattan, Manhattan
#  </div>
#  </div>
#  <div class="vspace-1" style="height: 15px;"></div>
#  <div id="listing-62453191-info">
#
#  <div class="d-inline-block align-middle" id="listing-62453191-price" style="line-height: 100%;">
#  <span class="font-size-20 b">$5,170</span>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  No Fee
#  </div>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  By Owner
#  </div>
#  </div>
#  </div>
#  <div class="font-size-8 font-gray-1 overflow-ellipsis" style="margin-top: 5px;">
#  By Columbus Square,
#  1 hour ago
#  </div>
#  <div class="vspace-1" style="height: 14px;"></div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bed.svg?30000010" style="width: 18px; height: 18px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 3px;">
#  1 Bed
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bath.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 3px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  1 Bath
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/ruler.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  657 Sqft
#  </div>
#  <div class="vspace-4"></div>
#  <div class="d-block d-md-none vspace-4"></div>
#  <div>
#  <div class="font-size-12 bold check-avail shadow-stripe text-center corner-8 b pointer" onclick='contact_listing_show("nyc", "62453191",
#             "1 Bedroom at 775 Columbus Avenue, Apt 07C")'>
#  Check Availability
#  </div>
#  </div>
#  </div>,
#  <div class="search-info d-block d-md-inline-block align-top">
#  <div>
#  <div class="float-right font-size-9" style="padding-top: 2px;">
#  <span class="font-gray-2 d-none d-sm-inline-block"></span>
#  </div>
#  <a class="font-size-12 b" href="https://www.renthop.com/listings/151-west-16th-street/3g/62765103" id="listing-62765103-title" style="text-decoration: none; line-height: 100%;">
#  151 West 16th Street, Apt 3G
#  </a>
#  <div class="font-gray-1 font-size-8 overflow-ellipsis" id="listing-62765103-neighborhoods" style="margin-top: 0px;">
#  Chelsea, Midtown Manhattan, Manhattan
#  </div>
#  </div>
#  <div class="vspace-1" style="height: 15px;"></div>
#  <div id="listing-62765103-info">
#
#  <div class="d-inline-block align-middle" id="listing-62765103-price" style="line-height: 100%;">
#  <span class="font-size-20 b">$3,000</span>
#  </div>
#  </div>
#  <div class="font-size-8 font-gray-1 overflow-ellipsis" style="margin-top: 5px;">
#  By Bianca Jenkins,
#  2 hours ago
#  </div>
#  <div class="vspace-1" style="height: 14px;"></div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bed.svg?30000010" style="width: 18px; height: 18px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 3px;">
#  Studio
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bath.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 3px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  1 Bath
#  </div>
#  <div class="vspace-4"></div>
#  <div class="d-block d-md-none vspace-4"></div>
#  <div>
#  <div class="font-size-12 bold check-avail shadow-stripe text-center corner-8 b pointer" onclick='contact_listing_show("nyc", "62765103",
#             "Studio at 151 West 16th Street, Apt 3G")'>
#  Check Availability
#  </div>
#  </div>
#  </div>,
#  <div class="search-info d-block d-md-inline-block align-top">
#  <div>
#  <div class="float-right font-size-9" style="padding-top: 2px;">
#  <span class="font-gray-2 d-none d-sm-inline-block"></span>
#  </div>
#  <a class="font-size-12 b" href="https://www.renthop.com/listings/404-east-11th-street/loft/61958609" id="listing-61958609-title" style="text-decoration: none; line-height: 100%;">
#  404 East 11th Street, Apt LOFT...
#  </a>
#  <div class="font-gray-1 font-size-8 overflow-ellipsis" id="listing-61958609-neighborhoods" style="margin-top: 0px;">
#  East Village, Downtown Manhattan, Manhattan
#  </div>
#  </div>
#  <div class="vspace-1" style="height: 15px;"></div>
#  <div id="listing-61958609-info">
#
#  <div class="d-inline-block align-middle" id="listing-61958609-price" style="line-height: 100%;">
#  <span class="font-size-20 b">$6,249</span>
#  </div>
#  </div>
#  <div class="font-size-8 font-gray-1 overflow-ellipsis" style="margin-top: 5px;">
#  By <a class="font-blue" href="https://www.renthop.com/managers/SuzanneG" style="text-decoration: none;">Suzanne Goldklang</a>,
#  1 hour ago
#  </div>
#  <div class="vspace-1" style="height: 14px;"></div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bed.svg?30000010" style="width: 18px; height: 18px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 3px;">
#  1 Bed
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bath.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 3px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  2 Bath
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/ruler.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  1,153 Sqft
#  </div>
#  <div class="vspace-4"></div>
#  <div class="d-block d-md-none vspace-4"></div>
#  <div>
#  <div class="font-size-12 bold check-avail shadow-stripe text-center corner-8 b pointer" onclick='contact_listing_show("nyc", "61958609",
#             "1 Bedroom at 404 East 11th Street, Apt LOFT...")'>
#  Check Availability
#  </div>
#  </div>
#  </div>,
#  <div class="search-info d-block d-md-inline-block align-top">
#  <div>
#  <div class="float-right font-size-9" style="padding-top: 2px;">
#  <span class="font-gray-2 d-none d-sm-inline-block"></span>
#  </div>
#  <a class="font-size-12 b" href="https://www.renthop.com/listings/5241-center-boulevard/4502-penthouse/61892082" id="listing-61892082-title" style="text-decoration: none; line-height: 100%;">
#  5241 Center Boulevard, Apt 450...
#  </a>
#  <div class="font-gray-1 font-size-8 overflow-ellipsis" id="listing-61892082-neighborhoods" style="margin-top: 0px;">
#  Hunters Point, Long Island City, Northwestern Queens, Queens
#  </div>
#  </div>
#  <div class="vspace-1" style="height: 15px;"></div>
#  <div id="listing-61892082-info">
#
#  <div class="d-inline-block align-middle" id="listing-61892082-price" style="line-height: 100%;">
#  <span class="font-size-20 b">$6,199</span>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  No Fee
#  </div>
#  </div>
#  </div>
#  <div class="font-size-8 font-gray-1 overflow-ellipsis" style="margin-top: 5px;">
#  By Don Abbott,
#  1 hour ago
#  </div>
#  <div class="vspace-1" style="height: 14px;"></div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bed.svg?30000010" style="width: 18px; height: 18px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 3px;">
#  2 Bed
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bath.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 3px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  2 Bath
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/ruler.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  1,300 Sqft
#  </div>
#  <div class="vspace-4"></div>
#  <div class="d-block d-md-none vspace-4"></div>
#  <div>
#  <div class="font-size-12 bold check-avail shadow-stripe text-center corner-8 b pointer" onclick='contact_listing_show("nyc", "61892082",
#             "2 Bedrooms at 5241 Center Boulevard, Apt 450...")'>
#  Check Availability
#  </div>
#  </div>
#  </div>,
#  <div class="search-info d-block d-md-inline-block align-top">
#  <div>
#  <div class="float-right font-size-9" style="padding-top: 2px;">
#  <span class="font-gray-2 d-none d-sm-inline-block"></span>
#  </div>
#  <a class="font-size-12 b" href="https://www.renthop.com/listings/208-e-83rd-st/2w/62181262" id="listing-62181262-title" style="text-decoration: none; line-height: 100%;">
#  208 E 83rd St, Apt 2W
#  </a>
#  <div class="font-gray-1 font-size-8 overflow-ellipsis" id="listing-62181262-neighborhoods" style="margin-top: 0px;">
#  Yorkville, Upper East Side, Upper Manhattan, Manhattan
#  </div>
#  </div>
#  <div class="vspace-1" style="height: 15px;"></div>
#  <div id="listing-62181262-info">
#
#  <div class="d-inline-block align-middle" id="listing-62181262-price" style="line-height: 100%;">
#  <span class="font-size-20 b">$2,995</span>
#  </div>
#  </div>
#  <div class="font-size-8 font-gray-1 overflow-ellipsis" style="margin-top: 5px;">
#  By Ariel Sassoon,
#  1 hour ago
#  </div>
#  <div class="vspace-1" style="height: 14px;"></div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bed.svg?30000010" style="width: 18px; height: 18px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 3px;">
#  2 Bed
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bath.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 3px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  1 Bath
#  </div>
#  <div class="vspace-4"></div>
#  <div class="d-block d-md-none vspace-4"></div>
#  <div>
#  <div class="font-size-12 bold check-avail shadow-stripe text-center corner-8 b pointer" onclick='contact_listing_show("nyc", "62181262",
#             "2 Bedrooms at 208 E 83rd St, Apt 2W")'>
#  Check Availability
#  </div>
#  </div>
#  </div>,
#  <div class="search-info d-block d-md-inline-block align-top">
#  <div>
#  <div class="float-right font-size-9" style="padding-top: 2px;">
#  <span class="font-gray-2 d-none d-sm-inline-block"></span>
#  </div>
#  <a class="font-size-12 b" href="https://www.renthop.com/listings/95-wall-street/1818/62062314" id="listing-62062314-title" style="text-decoration: none; line-height: 100%;">
#  95 Wall Street, Apt 1818
#  </a>
#  <div class="font-gray-1 font-size-8 overflow-ellipsis" id="listing-62062314-neighborhoods" style="margin-top: 0px;">
#  Financial District, Downtown Manhattan, Manhattan
#  </div>
#  </div>
#  <div class="vspace-1" style="height: 15px;"></div>
#  <div id="listing-62062314-info">
#
#  <div class="d-inline-block align-middle" id="listing-62062314-price" style="line-height: 100%;">
#  <span class="font-size-20 b">$3,445</span>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  No Fee
#  </div>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  By Owner
#  </div>
#  </div>
#  </div>
#  <div class="font-size-8 font-gray-1 overflow-ellipsis" style="margin-top: 5px;">
#  By 95 Wall,
#  2 hours ago
#  </div>
#  <div class="vspace-1" style="height: 14px;"></div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bed.svg?30000010" style="width: 18px; height: 18px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 3px;">
#  Studio
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bath.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 3px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  1 Bath
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/ruler.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  636 Sqft
#  </div>
#  <div class="vspace-4"></div>
#  <div class="d-block d-md-none vspace-4"></div>
#  <div>
#  <div class="font-size-12 bold check-avail shadow-stripe text-center corner-8 b pointer" onclick='contact_listing_show("nyc", "62062314",
#             "Studio at 95 Wall Street, Apt 1818")'>
#  Check Availability
#  </div>
#  </div>
#  </div>,
#  <div class="search-info d-block d-md-inline-block align-top">
#  <div>
#  <div class="float-right font-size-9" style="padding-top: 2px;">
#  <span class="font-gray-2 d-none d-sm-inline-block"></span>
#  </div>
#  <a class="font-size-12 b" href="https://www.renthop.com/listings/561-10th-avenue/16/62513385" id="listing-62513385-title" style="text-decoration: none; line-height: 100%;">
#  561 10th Avenue, Apt 16А
#  </a>
#  <div class="font-gray-1 font-size-8 overflow-ellipsis" id="listing-62513385-neighborhoods" style="margin-top: 0px;">
#  Hell's Kitchen, Midtown Manhattan, Manhattan
#  </div>
#  </div>
#  <div class="vspace-1" style="height: 15px;"></div>
#  <div id="listing-62513385-info">
#
#  <div class="d-inline-block align-middle" id="listing-62513385-price" style="line-height: 100%;">
#  <span class="font-size-20 b">$3,600</span>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  No Fee
#  </div>
#  </div>
#  </div>
#  <div class="font-size-8 font-gray-1 overflow-ellipsis" style="margin-top: 5px;">
#  By Yordan Bobchev,
#  3 hours ago
#  </div>
#  <div class="vspace-1" style="height: 14px;"></div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bed.svg?30000010" style="width: 18px; height: 18px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 3px;">
#  1 Bed
#  / Flex 2 </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bath.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 3px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  1 Bath
#  </div>
#  <div class="vspace-4"></div>
#  <div class="d-block d-md-none vspace-4"></div>
#  <div>
#  <div class="font-size-12 bold check-avail shadow-stripe text-center corner-8 b pointer" onclick='contact_listing_show("nyc", "62513385",
#             "1 Bedroom at 561 10th Avenue, Apt 16А")'>
#  Check Availability
#  </div>
#  </div>
#  </div>,
#  <div class="search-info d-block d-md-inline-block align-top">
#  <div>
#  <div class="float-right font-size-9" style="padding-top: 2px;">
#  <span class="font-gray-2 d-none d-sm-inline-block"></span>
#  </div>
#  <a class="font-size-12 b" href="https://www.renthop.com/listings/95-wall-street/216/61980666" id="listing-61980666-title" style="text-decoration: none; line-height: 100%;">
#  95 Wall Street, Apt 216
#  </a>
#  <div class="font-gray-1 font-size-8 overflow-ellipsis" id="listing-61980666-neighborhoods" style="margin-top: 0px;">
#  Financial District, Downtown Manhattan, Manhattan
#  </div>
#  </div>
#  <div class="vspace-1" style="height: 15px;"></div>
#  <div id="listing-61980666-info">
#
#  <div class="d-inline-block align-middle" id="listing-61980666-price" style="line-height: 100%;">
#  <span class="font-size-20 b">$3,078</span>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  No Fee
#  </div>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  By Owner
#  </div>
#  </div>
#  </div>
#  <div class="font-size-8 font-gray-1 overflow-ellipsis" style="margin-top: 5px;">
#  By 95 Wall,
#  2 hours ago
#  </div>
#  <div class="vspace-1" style="height: 14px;"></div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bed.svg?30000010" style="width: 18px; height: 18px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 3px;">
#  Studio
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bath.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 3px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  1 Bath
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/ruler.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  487 Sqft
#  </div>
#  <div class="vspace-4"></div>
#  <div class="d-block d-md-none vspace-4"></div>
#  <div>
#  <div class="font-size-12 bold check-avail shadow-stripe text-center corner-8 b pointer" onclick='contact_listing_show("nyc", "61980666",
#             "Studio at 95 Wall Street, Apt 216")'>
#  Check Availability
#  </div>
#  </div>
#  </div>,
#  <div class="search-info d-block d-md-inline-block align-top">
#  <div>
#  <div class="float-right font-size-9" style="padding-top: 2px;">
#  <span class="font-gray-2 d-none d-sm-inline-block"></span>
#  </div>
#  <a class="font-size-12 b" href="https://www.renthop.com/listings/645-e-14th-st/03-h/62422173" id="listing-62422173-title" style="text-decoration: none; line-height: 100%;">
#  645 E 14th St, Apt 03H
#  </a>
#  <div class="font-gray-1 font-size-8 overflow-ellipsis" id="listing-62422173-neighborhoods" style="margin-top: 0px;">
#  Stuyvesant Town - Peter Cooper Village, Midtown Manhattan, Manhattan
#  </div>
#  </div>
#  <div class="vspace-1" style="height: 15px;"></div>
#  <div id="listing-62422173-info">
#
#  <div class="d-inline-block align-middle" id="listing-62422173-price" style="line-height: 100%;">
#  <span class="font-size-20 b">$5,214</span>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  No Fee
#  </div>
#  </div>
#  </div>
#  <div class="font-size-8 font-gray-1 overflow-ellipsis" style="margin-top: 5px;">
#  By Stuytown Leasing Team,
#  1 hour ago
#  </div>
#  <div class="vspace-1" style="height: 14px;"></div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bed.svg?30000010" style="width: 18px; height: 18px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 3px;">
#  2 Bed
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bath.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 3px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  1 Bath
#  </div>
#  <div class="vspace-4"></div>
#  <div class="d-block d-md-none vspace-4"></div>
#  <div>
#  <div class="font-size-12 bold check-avail shadow-stripe text-center corner-8 b pointer" onclick='contact_listing_show("nyc", "62422173",
#             "2 Bedrooms at 645 E 14th St, Apt 03H")'>
#  Check Availability
#  </div>
#  </div>
#  </div>,
#  <div class="search-info d-block d-md-inline-block align-top">
#  <div>
#  <div class="float-right font-size-9" style="padding-top: 2px;">
#  <span class="font-gray-2 d-none d-sm-inline-block"></span>
#  </div>
#  <a class="font-size-12 b" href="https://www.renthop.com/listings/2337-bedford-ave-brooklyn/4a/62655210" id="listing-62655210-title" style="text-decoration: none; line-height: 100%;">
#  2337 Bedford Avenue, Apt 4A
#  </a>
#  <div class="font-gray-1 font-size-8 overflow-ellipsis" id="listing-62655210-neighborhoods" style="margin-top: 0px;">
#  Flatbush, Central Brooklyn, Brooklyn
#  </div>
#  </div>
#  <div class="vspace-1" style="height: 15px;"></div>
#  <div id="listing-62655210-info">
#
#  <div class="d-inline-block align-middle" id="listing-62655210-price" style="line-height: 100%;">
#  <span class="font-size-20 b">$3,625</span>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  No Fee
#  </div>
#  </div>
#  </div>
#  <div class="font-size-8 font-gray-1 overflow-ellipsis" style="margin-top: 5px;">
#  By Lihi,
#  last 30 min
#  </div>
#  <div class="vspace-1" style="height: 14px;"></div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bed.svg?30000010" style="width: 18px; height: 18px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 3px;">
#  3 Bed
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bath.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 3px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  2 Bath
#  </div>
#  <div class="vspace-4"></div>
#  <div class="d-block d-md-none vspace-4"></div>
#  <div>
#  <div class="font-size-12 bold check-avail shadow-stripe text-center corner-8 b pointer" onclick='contact_listing_show("nyc", "62655210",
#             "3 Bedrooms at 2337 Bedford Avenue, Apt 4A")'>
#  Check Availability
#  </div>
#  </div>
#  </div>,
#  <div class="search-info d-block d-md-inline-block align-top">
#  <div>
#  <div class="float-right font-size-9" style="padding-top: 2px;">
#  <span class="font-gray-2 d-none d-sm-inline-block"></span>
#  </div>
#  <a class="font-size-12 b" href="https://www.renthop.com/listings/30-charlton-street/4-b/62751500" id="listing-62751500-title" style="text-decoration: none; line-height: 100%;">
#  30 Charlton Street, Apt 4B
#  </a>
#  <div class="font-gray-1 font-size-8 overflow-ellipsis" id="listing-62751500-neighborhoods" style="margin-top: 0px;">
#  Hudson Square, SoHo, Downtown Manhattan, Manhattan
#  </div>
#  </div>
#  <div class="vspace-1" style="height: 15px;"></div>
#  <div id="listing-62751500-info">
#
#  <div class="d-inline-block align-middle" id="listing-62751500-price" style="line-height: 100%;">
#  <span class="font-size-20 b">$7,495</span>
#  </div>
#  </div>
#  <div class="font-size-8 font-gray-1 overflow-ellipsis" style="margin-top: 5px;">
#  By Ofer Avital,
#  last hour
#  </div>
#  <div class="vspace-1" style="height: 14px;"></div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bed.svg?30000010" style="width: 18px; height: 18px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 3px;">
#  2 Bed
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bath.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 3px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  2 Bath
#  </div>
#  <div class="vspace-4"></div>
#  <div class="d-block d-md-none vspace-4"></div>
#  <div>
#  <div class="font-size-12 bold check-avail shadow-stripe text-center corner-8 b pointer" onclick='contact_listing_show("nyc", "62751500",
#             "2 Bedrooms at 30 Charlton Street, Apt 4B")'>
#  Check Availability
#  </div>
#  </div>
#  </div>,
#  <div class="search-info d-block d-md-inline-block align-top">
#  <div>
#  <div class="float-right font-size-9" style="padding-top: 2px;">
#  <span class="font-gray-2 d-none d-sm-inline-block"></span>
#  </div>
#  <a class="font-size-12 b" href="https://www.renthop.com/listings/119-east-97th-street/1r/62391529" id="listing-62391529-title" style="text-decoration: none; line-height: 100%;">
#  119 East 97th Street, Apt 1R
#  </a>
#  <div class="font-gray-1 font-size-8 overflow-ellipsis" id="listing-62391529-neighborhoods" style="margin-top: 0px;">
#  East Harlem, Upper Manhattan, Manhattan
#  </div>
#  </div>
#  <div class="vspace-1" style="height: 15px;"></div>
#  <div id="listing-62391529-info">
#
#  <div class="d-inline-block align-middle" id="listing-62391529-price" style="line-height: 100%;">
#  <span class="font-size-20 b">$1,950</span>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  No Fee
#  </div>
#  </div>
#  </div>
#  <div class="font-size-8 font-gray-1 overflow-ellipsis" style="margin-top: 5px;">
#  By Ofer Avital,
#  last hour
#  </div>
#  <div class="vspace-1" style="height: 14px;"></div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bed.svg?30000010" style="width: 18px; height: 18px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 3px;">
#  1 Bed
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bath.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 3px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  1 Bath
#  </div>
#  <div class="vspace-4"></div>
#  <div class="d-block d-md-none vspace-4"></div>
#  <div>
#  <div class="font-size-12 bold check-avail shadow-stripe text-center corner-8 b pointer" onclick='contact_listing_show("nyc", "62391529",
#             "1 Bedroom at 119 East 97th Street, Apt 1R")'>
#  Check Availability
#  </div>
#  </div>
#  </div>,
#  <div class="search-info d-block d-md-inline-block align-top">
#  <div>
#  <div class="float-right font-size-9" style="padding-top: 2px;">
#  <span class="font-gray-2 d-none d-sm-inline-block"></span>
#  </div>
#  <a class="font-size-12 b" href="https://www.renthop.com/listings/795-columbus-ave/16f/62659057" id="listing-62659057-title" style="text-decoration: none; line-height: 100%;">
#  795 Columbus Avenue, Apt 16F
#  </a>
#  <div class="font-gray-1 font-size-8 overflow-ellipsis" id="listing-62659057-neighborhoods" style="margin-top: 0px;">
#  Manhattan Valley, Upper West Side, Upper Manhattan, Manhattan
#  </div>
#  </div>
#  <div class="vspace-1" style="height: 15px;"></div>
#  <div id="listing-62659057-info">
#
#  <div class="d-inline-block align-middle" id="listing-62659057-price" style="line-height: 100%;">
#  <span class="font-size-20 b">$3,531</span>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  No Fee
#  </div>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  By Owner
#  </div>
#  </div>
#  </div>
#  <div class="font-size-8 font-gray-1 overflow-ellipsis" style="margin-top: 5px;">
#  By Columbus Square,
#  2 hours ago
#  </div>
#  <div class="vspace-1" style="height: 14px;"></div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bed.svg?30000010" style="width: 18px; height: 18px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 3px;">
#  Studio
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#   <img src="/images/renthop/bath.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 3px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  1 Bath
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/ruler.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  447 Sqft
#  </div>
#  <div class="vspace-4"></div>
#  <div class="d-block d-md-none vspace-4"></div>
#  <div>
#  <div class="font-size-12 bold check-avail shadow-stripe text-center corner-8 b pointer" onclick='contact_listing_show("nyc", "62659057",
#             "Studio at 795 Columbus Avenue, Apt 16F")'>
#  Check Availability
#  </div>
#  </div>
#  </div>,
#  <div class="search-info d-block d-md-inline-block align-top">
#  <div>
#  <div class="float-right font-size-9" style="padding-top: 2px;">
#  <span class="font-gray-2 d-none d-sm-inline-block"></span>
#  </div>
#  <a class="font-size-12 b" href="https://www.renthop.com/listings/10-hanover-square/19w/62461963" id="listing-62461963-title" style="text-decoration: none; line-height: 100%;">
#  10 Hanover Square, Apt 19W
#  </a>
#  <div class="font-gray-1 font-size-8 overflow-ellipsis" id="listing-62461963-neighborhoods" style="margin-top: 0px;">
#  Financial District, Downtown Manhattan, Manhattan
#  </div>
#  </div>
#  <div class="vspace-1" style="height: 15px;"></div>
#  <div id="listing-62461963-info">
#
#  <div class="d-inline-block align-middle" id="listing-62461963-price" style="line-height: 100%;">
#  <span class="font-size-20 b">$4,697</span>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  No Fee
#  </div>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  By Owner
#  </div>
#  </div>
#  </div>
#  <div class="font-size-8 font-gray-1 overflow-ellipsis" style="margin-top: 5px;">
#  By 10 Hanover Square,
#  1 hour ago
#  </div>
#  <div class="vspace-1" style="height: 14px;"></div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bed.svg?30000010" style="width: 18px; height: 18px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 3px;">
#  1 Bed
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bath.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 3px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  1 Bath
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/ruler.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  851 Sqft
#  </div>
#  <div class="vspace-4"></div>
#  <div class="d-block d-md-none vspace-4"></div>
#  <div>
#  <div class="font-size-12 bold check-avail shadow-stripe text-center corner-8 b pointer" onclick='contact_listing_show("nyc", "62461963",
#             "1 Bedroom at 10 Hanover Square, Apt 19W")'>
#  Check Availability
#  </div>
#  </div>
#  </div>,
#  <div class="search-info d-block d-md-inline-block align-top">
#  <div>
#  <div class="float-right font-size-9" style="padding-top: 2px;">
#  <span class="font-gray-2 d-none d-sm-inline-block"></span>
#  </div>
#  <a class="font-size-12 b" href="https://www.renthop.com/listings/160-west-73rd-street/14c/62775137" id="listing-62775137-title" style="text-decoration: none; line-height: 100%;">
#  160 West 73rd Street, Apt 14C
#  </a>
#  <div class="font-gray-1 font-size-8 overflow-ellipsis" id="listing-62775137-neighborhoods" style="margin-top: 0px;">
#  Upper West Side, Upper Manhattan, Manhattan
#  </div>
#  </div>
#  <div class="vspace-1" style="height: 15px;"></div>
#  <div id="listing-62775137-info">
#
#  <div class="d-inline-block align-middle" id="listing-62775137-price" style="line-height: 100%;">
#  <span class="font-size-20 b">$3,950</span>
#  </div>
#  </div>
#  <div class="font-size-8 font-gray-1 overflow-ellipsis" style="margin-top: 5px;">
#  By Ted Fernandez,
#  1 hour ago
#  </div>
#  <div class="vspace-1" style="height: 14px;"></div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bed.svg?30000010" style="width: 18px; height: 18px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 3px;">
#  1 Bed
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bath.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 3px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  1 Bath
#  </div>
#  <div class="vspace-4"></div>
#  <div class="d-block d-md-none vspace-4"></div>
#  <div>
#  <div class="font-size-12 bold check-avail shadow-stripe text-center corner-8 b pointer" onclick='contact_listing_show("nyc", "62775137",
#             "1 Bedroom at 160 West 73rd Street, Apt 14C")'>
#  Check Availability
#  </div>
#  </div>
#  </div>,
#  <div class="search-info d-block d-md-inline-block align-top">
#  <div>
#  <div class="float-right font-size-9" style="padding-top: 2px;">
#  <span class="font-gray-2 d-none d-sm-inline-block"></span>
#  </div>
#  <a class="font-size-12 b" href="https://www.renthop.com/listings/120-w-21st/305/62293140" id="listing-62293140-title" style="text-decoration: none; line-height: 100%;">
#  120 W. 21st, Apt 305
#  </a>
#  <div class="font-gray-1 font-size-8 overflow-ellipsis" id="listing-62293140-neighborhoods" style="margin-top: 0px;">
#  Chelsea, Midtown Manhattan, Manhattan
#  </div>
#  </div>
#  <div class="vspace-1" style="height: 15px;"></div>
#  <div id="listing-62293140-info">
#
#  <div class="d-inline-block align-middle" id="listing-62293140-price" style="line-height: 100%;">
#  <span class="font-size-20 b">$4,879</span>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  No Fee
#  </div>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  By Owner
#  </div>
#  </div>
#  </div>
#  <div class="font-size-8 font-gray-1 overflow-ellipsis" style="margin-top: 5px;">
#  By 21 Chelsea,
#  1 hour ago
#  </div>
#  <div class="vspace-1" style="height: 14px;"></div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bed.svg?30000010" style="width: 18px; height: 18px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 3px;">
#  1 Bed
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bath.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 3px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  1 Bath
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/ruler.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  607 Sqft
#  </div>
#  <div class="vspace-4"></div>
#  <div class="d-block d-md-none vspace-4"></div>
#  <div>
#  <div class="font-size-12 bold check-avail shadow-stripe text-center corner-8 b pointer" onclick='contact_listing_show("nyc", "62293140",
#             "1 Bedroom at 120 W. 21st, Apt 305")'>
#  Check Availability
#  </div>
#  </div>
#  </div>,
#  <div class="search-info d-block d-md-inline-block align-top">
#  <div>
#  <div class="float-right font-size-9" style="padding-top: 2px;">
#  <span class="font-gray-2 d-none d-sm-inline-block"></span>
#  </div>
#  <a class="font-size-12 b" href="https://www.renthop.com/listings/e95-between-2nd-and-3rd-avenue/27d/62438907" id="listing-62438907-title" style="text-decoration: none; line-height: 100%;">
#  E95 Between 2nd and 3rd Avenue...
#  </a>
#  <div class="font-gray-1 font-size-8 overflow-ellipsis" id="listing-62438907-neighborhoods" style="margin-top: 0px;">
#  Yorkville, Upper East Side, Upper Manhattan, Manhattan
#  </div>
#  </div>
#  <div class="vspace-1" style="height: 15px;"></div>
#  <div id="listing-62438907-info">
#
#  <div class="d-inline-block align-middle" id="listing-62438907-price" style="line-height: 100%;">
#  <span class="font-size-20 b">$4,600</span>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  No Fee
#  </div>
#  </div>
#  </div>
#  <div class="font-size-8 font-gray-1 overflow-ellipsis" style="margin-top: 5px;">
#  By <a class="font-blue" href="https://www.renthop.com/managers/cica-hansen-dragica" style="text-decoration: none;">Cica Hansen (Dragica)</a>,
#  last hour
#  </div>
#  <div class="vspace-1" style="height: 14px;"></div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bed.svg?30000010" style="width: 18px; height: 18px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 3px;">
#  2 Bed
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bath.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 3px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  1.5 Bath
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/ruler.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  936 Sqft
#  </div>
#  <div class="vspace-4"></div>
#  <div class="d-block d-md-none vspace-4"></div>
#  <div>
#  <div class="font-size-12 bold check-avail shadow-stripe text-center corner-8 b pointer" onclick='contact_listing_show("nyc", "62438907",
#             "2 Bedrooms at E95 Between 2nd and 3rd Avenue...")'>
#  Check Availability
#  </div>
#  </div>
#  </div>,
#  <div class="search-info d-block d-md-inline-block align-top">
#  <div>
#  <div class="float-right font-size-9" style="padding-top: 2px;">
#  <span class="font-gray-2 d-none d-sm-inline-block"></span>
#  </div>
#  <a class="font-size-12 b" href="https://www.renthop.com/listings/395-leonard-street/616/62668098" id="listing-62668098-title" style="text-decoration: none; line-height: 100%;">
#  395 Leonard Street, Apt 616
#  </a>
#  <div class="font-gray-1 font-size-8 overflow-ellipsis" id="listing-62668098-neighborhoods" style="margin-top: 0px;">
#  Williamsburg, Northern Brooklyn, Brooklyn
#  </div>
#  </div>
#  <div class="vspace-1" style="height: 15px;"></div>
#  <div id="listing-62668098-info">
#
#  <div class="d-inline-block align-middle" id="listing-62668098-price" style="line-height: 100%;">
#  <span class="font-size-20 b">$4,127</span>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  No Fee
#  </div>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  By Owner
#  </div>
#  </div>
#  </div>
#  <div class="font-size-8 font-gray-1 overflow-ellipsis" style="margin-top: 5px;">
#  By Leonard Pointe,
#  1 hour ago
#  </div>
#  <div class="vspace-1" style="height: 14px;"></div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bed.svg?30000010" style="width: 18px; height: 18px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 3px;">
#  1 Bed
#   </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bath.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 3px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  1 Bath
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/ruler.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  680 Sqft
#  </div>
#  <div class="vspace-4"></div>
#  <div class="d-block d-md-none vspace-4"></div>
#  <div>
#  <div class="font-size-12 bold check-avail shadow-stripe text-center corner-8 b pointer" onclick='contact_listing_show("nyc", "62668098",
#             "1 Bedroom at 395 Leonard Street, Apt 616")'>
#  Check Availability
#  </div>
#  </div>
#  </div>,
#  <div class="search-info d-block d-md-inline-block align-top">
#  <div>
#  <div class="float-right font-size-9" style="padding-top: 2px;">
#  <span class="font-gray-2 d-none d-sm-inline-block"></span>
#  </div>
#  <a class="font-size-12 b" href="https://www.renthop.com/listings/3rd-ave-e-87th-st/23n/59083735" id="listing-59083735-title" style="text-decoration: none; line-height: 100%;">
#  3rd Ave &amp; E 87th St
#  </a>
#  <div class="font-gray-1 font-size-8 overflow-ellipsis" id="listing-59083735-neighborhoods" style="margin-top: 0px;">
#  Yorkville, Upper East Side, Upper Manhattan, Manhattan
#  </div>
#  </div>
#  <div class="vspace-1" style="height: 15px;"></div>
#  <div id="listing-59083735-info">
#
#  <div class="d-inline-block align-middle" id="listing-59083735-price" style="line-height: 100%;">
#  <span class="font-size-20 b">$3,518</span>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  No Fee
#  </div>
#  </div>
#  </div>
#  <div class="font-size-8 font-gray-1 overflow-ellipsis" style="margin-top: 5px;">
#  By <a class="font-blue" href="https://www.renthop.com/managers/samantha-zerbe" style="text-decoration: none;">Samantha Zerbe</a>,
#  1 hour ago
#  </div>
#  <div class="vspace-1" style="height: 14px;"></div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bed.svg?30000010" style="width: 18px; height: 18px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 3px;">
#  1 Bed
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bath.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 3px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  1 Bath
#  </div>
#  <div class="vspace-4"></div>
#  <div class="d-block d-md-none vspace-4"></div>
#  <div>
#  <div class="font-size-12 bold check-avail shadow-stripe text-center corner-8 b pointer" onclick='contact_listing_show("nyc", "59083735",
#             "1 Bedroom at 3rd Ave &amp; E 87th St")'>
#  Check Availability
#  </div>
#  </div>
#  </div>,
#  <div class="search-info d-block d-md-inline-block align-top">
#  <div>
#  <div class="float-right font-size-9" style="padding-top: 2px;">
#  <span class="font-gray-2 d-none d-sm-inline-block"></span>
#  </div>
#  <a class="font-size-12 b" href="https://www.renthop.com/listings/444-east-81st-street/2/62624845" id="listing-62624845-title" style="text-decoration: none; line-height: 100%;">
#  444 East 81st Street, Apt 2
#  </a>
#  <div class="font-gray-1 font-size-8 overflow-ellipsis" id="listing-62624845-neighborhoods" style="margin-top: 0px;">
#  Yorkville, Upper East Side, Upper Manhattan, Manhattan
#  </div>
#  </div>
#  <div class="vspace-1" style="height: 15px;"></div>
#  <div id="listing-62624845-info">
#
#  <div class="d-inline-block align-middle" id="listing-62624845-price" style="line-height: 100%;">
#  <span class="font-size-20 b">$2,950</span>
#  </div>
#  </div>
#  <div class="font-size-8 font-gray-1 overflow-ellipsis" style="margin-top: 5px;">
#  By <a class="font-blue" href="https://www.renthop.com/managers/sivan-aharon" style="text-decoration: none;">Sivan Aharon</a>,
#  5 hours ago
#  </div>
#  <div class="vspace-1" style="height: 14px;"></div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bed.svg?30000010" style="width: 18px; height: 18px; margin-bottom: 2px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 3px;">
#  1 Bed
#  </div>
#  <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
#  |
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom">
#  <img src="/images/renthop/bath.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 3px;"/>
#  </div>
#  <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
#  1 Bath
#  </div>
#
#  <div class="vspace-4"></div>
#  <div class="d-block d-md-none vspace-4"></div>
#  <div>
#  <div class="font-size-12 bold check-avail shadow-stripe text-center corner-8 b pointer" onclick='contact_listing_show("nyc", "62624845",
#             "1 Bedroom at 444 East 81st Street, Apt 2")'>
#  Check Availability
#  </div>
#  </div>
#  </div>]

# %% [markdown]
# by the looking task we see that there should be twenty divs aprox. Let's confirm with `len(listing_divs)`

# %%
len(listing_divs)
# Out:
# 20

# %% [markdown]
# ## Pulling the individual data points
#
# We need to pull out the individual data points for each apartments. The points we want are:
#
# - URL of the listing
# - Address of the apartment
# - Neighborhood
# - Number of Bedrooms
# - Number of bathrooms
#
# More data could be more significant like square footage, etc. there are not here.
#
# Let's cheeck the first listing

# %%
listing_divs[0]
# Out:
# <div class="search-info d-block d-md-inline-block align-top">
# <div>
# <div class="float-right font-size-9" style="padding-top: 2px;">
# <span class="font-gray-2 d-none d-sm-inline-block"></span>
# </div>
# <a class="font-size-12 b" href="https://www.renthop.com/listings/775-columbus-ave/07c/62453191" id="listing-62453191-title" style="text-decoration: none; line-height: 100%;">
# 775 Columbus Avenue, Apt 07C
# </a>
# <div class="font-gray-1 font-size-8 overflow-ellipsis" id="listing-62453191-neighborhoods" style="margin-top: 0px;">
# Manhattan Valley, Upper West Side, Upper Manhattan, Manhattan
# </div>
# </div>
# <div class="vspace-1" style="height: 15px;"></div>
# <div id="listing-62453191-info">
#
# <div class="d-inline-block align-middle" id="listing-62453191-price" style="line-height: 100%;">
# <span class="font-size-20 b">$5,170</span>
# </div>
# <div class="d-inline-block">
# <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
# No Fee
# </div>
# </div>
# <div class="d-inline-block">
# <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
# By Owner
# </div>
# </div>
# </div>
# <div class="font-size-8 font-gray-1 overflow-ellipsis" style="margin-top: 5px;">
# By Columbus Square,
# 1 hour ago
# </div>
# <div class="vspace-1" style="height: 14px;"></div>
# <div class="font-size-10 d-inline-block align-bottom">
# <img src="/images/renthop/bed.svg?30000010" style="width: 18px; height: 18px; margin-bottom: 2px;"/>
# </div>
# <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 3px;">
# 1 Bed
# </div>
# <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
# |
# </div>
# <div class="font-size-10 d-inline-block align-bottom">
# <img src="/images/renthop/bath.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 3px;"/>
# </div>
# <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
# 1 Bath
# </div>
# <div class="font-size-12 d-inline-block font-gray-4" style="padding: 0px 4px 0px 4px;">
# |
# </div>
# <div class="font-size-10 d-inline-block align-bottom">
# <img src="/images/renthop/ruler.svg?30000010" style="width: 17px; height: 17px; margin-bottom: 2px;"/>
# </div>
# <div class="font-size-10 d-inline-block align-bottom" style="margin-left: 1px;">
# 657 Sqft
# </div>
# <div class="vspace-4"></div>
# <div class="d-block d-md-none vspace-4"></div>
# <div>
# <div class="font-size-12 bold check-avail shadow-stripe text-center corner-8 b pointer" onclick='contact_listing_show("nyc", "62453191",
#            "1 Bedroom at 775 Columbus Avenue, Apt 07C")'>
# Check Availability
# </div>
# </div>
# </div>

# %% [markdown]
# The first ´div´ contains all the data points we're looking for, so there's no necessity to keep all.
#
# We need to begin our parse to target them each individually.
#
# The URL for the page is with an anchor or a tag, Let's parse that out now with another `select` statement.

# %%
print(listing_divs[0].select('a[id*=title]')[0]['href'])

print(listing_divs[0].select('div[id*=hood]')[0])
# Out:
# https://www.renthop.com/listings/775-columbus-ave/07c/62453191
# <div class="font-gray-1 font-size-8 overflow-ellipsis" id="listing-62453191-neighborhoods" style="margin-top: 0px;">
# Manhattan Valley, Upper West Side, Upper Manhattan, Manhattan
# </div>

# %% [markdown]
# That's the info ww want! Now, we can retrieve the other data points for the listing.

# %%
# First check the first listing div.
href = listing_divs[0].select('a[id*=title]')[0]['href']
addy = listing_divs[0].select('a[id*=title]')[0].string
hood = listing_divs[0].select('div[id*=hood]')[0].string.replace('\n', '')

# Verify this by printing what we got.
print(href)
print(addy)
print(hood)
# Out:
# https://www.renthop.com/listings/775-columbus-ave/07c/62453191
#
# 775 Columbus Avenue, Apt 07C
#
# Manhattan Valley, Upper West Side, Upper Manhattan, Manhattan

# %% [markdown]
# Now we get the address!
#
# Let's continue with the other items: bedrooms, bathrooms and price.
#
# Since they are in a table tag in a div and then inside a table row, we need to iterate
# over each point to capture the data.
#
# **NOTE**
# The original book states thath paragraph, but at the moment this notebook is written, the data is not in a table but
# in a div with id*=info. So you must change the follow line to the next:
#
# `listing_specs = listing_divs[0].select('table[id*=info] tr')`
#
# to
#
# `listing_specs = listing_divs[0].select('div[id*=info]')`

# %%
listing_specs = listing_divs[0].select('div[id*=info]')

for spec in listing_specs:
    spec_data = spec.text.strip().replace(' ', '_').split()
    print(spec_data)
# Out:
# ['$5,170', 'No_Fee', 'By_Owner']

# %%
listing_specs
# Out:
# [<div id="listing-62453191-info">
#
#  <div class="d-inline-block align-middle" id="listing-62453191-price" style="line-height: 100%;">
#  <span class="font-size-20 b">$5,170</span>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  No Fee
#  </div>
#  </div>
#  <div class="d-inline-block">
#  <div class="font-size-7 font-blue ml-1 b" style="line-height: 100%; background-color: var(--blue-dark-t-10); padding: 4px 6px 3px 6px;">
#  By Owner
#  </div>
#  </div>
#  </div>]
